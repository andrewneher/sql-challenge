# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import username, password
from scipy.stats import linregress
import os

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/homework_db')
connection = engine.connect()

# %%
connection = engine.connect()

# %%
employees_df = pd.read_sql('select * from employees', engine)
employees_df
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# 300019  1988-10-28
# 300020  1995-02-26
# 300021  1988-02-24
# 300022  1994-09-08
# 300023  1987-11-23
#
# [300024 rows x 7 columns]

# %%
departments_df = pd.read_sql('SELECT * FROM departments', engine)
departments_df
# Out:
#   dept_no           dept_name
# 0    d001           Marketing
# 1    d002             Finance
# 2    d003     Human Resources
# 3    d004          Production
# 4    d005         Development
# 5    d006  Quality Management
# 6    d007               Sales
# 7    d008            Research
# 8    d009    Customer Service

# %%
dept_emp_df = pd.read_sql('SELECT * FROM dept_emp', engine)
dept_emp_df
# Out:
#         emp_no dept_no
# 0        10001    d005
# 1        10002    d007
# 2        10003    d004
# 3        10004    d004
# 4        10005    d003
# ...        ...     ...
# 331598  499995    d004
# 331599  499996    d004
# 331600  499997    d005
# 331601  499998    d002
# 331602  499999    d004
#
# [331603 rows x 2 columns]

# %%
dept_manager_df = pd.read_sql('SELECT * FROM dept_manager', engine)
dept_manager_df
# Out:
#    dept_no  emp_no
# 0     d001  110022
# 1     d001  110039
# 2     d002  110085
# 3     d002  110114
# 4     d003  110183
# 5     d003  110228
# 6     d004  110303
# 7     d004  110344
# 8     d004  110386
# 9     d004  110420
# 10    d005  110511
# 11    d005  110567
# 12    d006  110725
# 13    d006  110765
# 14    d006  110800
# 15    d006  110854
# 16    d007  111035
# 17    d007  111133
# 18    d008  111400
# 19    d008  111534
# 20    d009  111692
# 21    d009  111784
# 22    d009  111877
# 23    d009  111939

# %%
salaries_df = pd.read_sql('SELECT * FROM salaries', engine)
salaries_df
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
titles_df = pd.read_sql('SELECT * FROM titles', engine)
titles_df
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
salary = salaries_df['salary']
salary
# Out:
# 0         60117
# 1         65828
# 2         40006
# 3         40054
# 4         78228
#           ...
# 300019    40000
# 300020    58058
# 300021    49597
# 300022    40000
# 300023    63707
# Name: salary, Length: 300024, dtype: int64

# %%
salary_merged = pd.merge(salaries_df, employees_df, on="emp_no", how='left')
# Display the data table for preview
salary_merged
# Out:
#         emp_no  salary emp_title_id  birth_date first_name last_name sex  \
# 0        10001   60117        e0003  1953-09-02     Georgi   Facello   M
# 1        10002   65828        s0001  1964-06-02    Bezalel    Simmel   F
# 2        10003   40006        e0003  1959-12-03      Parto   Bamford   M
# 3        10004   40054        e0003  1954-05-01  Chirstian   Koblick   M
# 4        10005   78228        s0001  1955-01-21    Kyoichi  Maliniak   M
# ...        ...     ...          ...         ...        ...       ...  ..
# 300019  499995   40000        e0002  1958-09-24     Dekang  Lichtner   F
# 300020  499996   58058        e0003  1953-03-07       Zito      Baaz   M
# 300021  499997   49597        e0003  1961-08-03    Berhard    Lenart   M
# 300022  499998   40000        s0001  1956-09-05   Patricia   Breugel   M
# 300023  499999   63707        e0002  1958-05-01     Sachin   Tsukuda   M
#
#          hire_date
# 0       1986-06-26
# 1       1985-11-21
# 2       1986-08-28
# 3       1986-12-01
# 4       1989-09-12
# ...            ...
# 300019  1993-01-12
# 300020  1990-09-27
# 300021  1986-04-21
# 300022  1993-10-13
# 300023  1997-11-30
#
# [300024 rows x 8 columns]

# %%
#group by employee title
salary_by_title = salary_merged.groupby(['emp_title_id']).mean()
#calculate salary
salary_by_title
# Out:
#                      emp_no        salary
# emp_title_id
# e0001         252992.595373  48564.434447
# e0002         253654.345919  48535.336511
# e0003         253038.749885  48506.799871
# e0004         251811.432730  48582.896092
# m0001         110780.833333  51531.041667
# s0001         253408.503604  58465.382850
# s0002         254481.798969  58550.172704

# %%
#1. Create a histogram to visualize the most common salary ranges for employees.
avg_salary = salaries_df['salary'].mean()
avg_salary
# Out:
# 52970.732451403885

# %%
salary_merged['salary'].hist(by=salary_merged['emp_title_id'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93CFAB20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C93DAF490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C9422A8E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94244D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C949B71C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C949D1550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C949D1640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94A06DF0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026C94A1E6A0>]],
#       dtype=object)

# %%
#2. Create a bar chart of average salary by title.
plt.bar(salary_merged['emp_title_id'], salary_merged['salary'], color="orange", alpha = .6)
plt.xlabel("Employee Title")
plt.ylabel("Salary")
plt.grid(True, alpha=.5)

# %%
#2. Create a bar chart of average salary by title.
plt.bar(salary_by_title['emp_title_id'], salary_by_title['salary'], color="pink", alpha = .6)
plt.xlabel("Employee Title")
plt.ylabel("Average Salary")
plt.grid(True, alpha=.5)
